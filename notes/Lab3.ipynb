# %%
# task deadline was 11 55 30 sec

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
import pandas as pd

# %%
def neuron2(x,w):
    return x@w

# %%
boston = fetch_openml(name="boston", version=1, as_frame=True)

# %%
df = boston.frame

# %%
plt.figure(figsize=(5, 3))
plt.scatter(df['LSTAT'], df['MEDV'])
#x_1 = np.linspace(df['LSTAT'].min(), df["LSTAT"].max())
x_1 = df["LSTAT"]
x_b = np.zeros_like(x_1)
x = np.vstack([x_1,x_b]).T
w = np.array([0.3,1])
y_pred = neuron2(x, w)
error = (df["MEDV"].values - y_pred)
mse = np.mean(error**2)
plt.title(mse)
plt.plot(x_1,y_pred, c='r')
plt.scatter(df['LSTAT'][0], df['MEDV'][0], color="black")

# %%
def correct_weights(x_n, y_n, w):
    w_0 = (y_n + w[1])/x_n
    w_1 = w_0*x_n-y_n
    return w_0, w_1

# %%
w_0, w_1 = correct_weights(x, y_pred, w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 w_0, w_1 = correct_weights(x, y_pred, w)
#
# Cell In[41], line 2, in correct_weights(x_n, y_n, w)
#       1 def correct_weights(x_n, y_n, w):
# ----> 2     w_0 = (y_n + w[1])/x_n
#       3     w_1 = w_0*x_n-y_n
#       4     return w_0, w_1
#
# ValueError: operands could not be broadcast together with shapes (506,) (506,2)

# %%
w_0, w_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 w_0, w_1
#
# NameError: name 'w_0' is not defined

# %%
w = np.array([5.02,1])

# %%
plt.figure(figsize=(5, 3))
plt.scatter(df['LSTAT'], df['MEDV'])
#x_1 = np.linspace(df['LSTAT'].min(), df["LSTAT"].max())
x_1 = df["LSTAT"]
x_b = np.zeros_like(x_1)
x = np.vstack([x_1,x_b]).T

difference = 0

for i in range(len(x_1)):
    x_n, y_n = df['LSTAT'][i], df['MEDV'][i]
    alpha = 0.01
    difference += alpha*np.array(correct_weights(x_n, y_n, w))
    change = difference/len(x_1)

w -= change
print(change)

y_pred = neuron2(x, w)
error = (df["MEDV"].values - y_pred)
mse = np.mean(error**2)
plt.title(mse)
plt.plot(x_1,y_pred, c='r')
plt.scatter(x_n, y_n, color="black")
# Out:
# [0.03220016 0.01      ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 19
#      16 w -= change
#      17 print(change)
# ---> 19 y_pred = neuron2(x, w)
#      20 error = (df["MEDV"].values - y_pred)
#      21 mse = np.mean(error**2)
#
# NameError: name 'neuron2' is not defined

# %%
w = np.array([0.22925899, 0.12375   ])

# %%
plt.figure(figsize=(5, 3))
plt.scatter(df['LSTAT'], df['MEDV'])
#x_1 = np.linspace(df['LSTAT'].min(), df["LSTAT"].max())
x_1 = df["LSTAT"]
x_b = np.zeros_like(x_1)
x = np.vstack([x_1,x_b]).T

y_pred = neuron2(x, w)
y_actual = df["MEDV"]
mse_val = mse(y_actual, y_pred)
plt.title(mse_val)
plt.plot(x_1,y_pred, c='r')
plt.scatter(x_n, y_n, color="black")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       5 x_b = np.zeros_like(x_1)
#       6 x = np.vstack([x_1,x_b]).T
# ----> 8 y_pred = neuron2(x, w)
#       9 y_actual = df["MEDV"]
#      10 mse_val = mse(y_actual, y_pred)
#
# NameError: name 'neuron2' is not defined

# %%
def mse(y_actual, y_predicted):
    return np.mean((y_actual - y_predicted)**2)

# %%
def l_mse(X,y, w):
    y_pred = neuron2(X,w)
    return mse(y, y_pre
# Out:
#   Cell In[24], line 3
#     return mse(y, y_pre
#                        ^
# SyntaxError: incomplete input

# %%
w2 = np.array([0.22925899, 1.12375   ])
w3 = np.array([3.22925899, 0.12375   ])


w2_loss = l_mse(X_train, y_train, w2)
print(f"Model 1 (w=[-0.6, 30]) Loss: {w2_loss:.2f}")

w3_loss = l_mse(X_train, y_train, w3)
print(f"Model 2 (w=[-0.8, 30]) Loss: {w3_loss:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       1 w2 = np.array([0.22925899, 1.12375   ])
#       2 w3 = np.array([3.22925899, 0.12375   ])
# ----> 5 w2_loss = l_mse(X_train, y_train, w2)
#       6 print(f"Model 1 (w=[-0.6, 30]) Loss: {w2_loss:.2f}")
#       8 w3_loss = l_mse(X_train, y_train, w3)
#
# NameError: name 'l_mse' is not defined

# %%
def mse_gradient(X,y,w):
    y_pred = neuron2(X,w)
    gradient = -(2/len(y)) * X.T @ (y - y_pred)
    return gradient

# %%
mse_gradient(X_train, y_train, w2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mse_gradient(X_train, y_train, w2)
#
# NameError: name 'X_train' is not defined

# %%
mse_gradient(X_train, y_train, w3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 mse_gradient(X_train, y_train, w3)
#
# NameError: name 'X_train' is not defined

# %%
plt.figure(figsize=(5, 3))
w = np.array([4.22925899, 6.12375   ])
plt.scatter(df['LSTAT'], df['MEDV'])
#x_1 = np.linspace(df['LSTAT'].min(), df["LSTAT"].max())
X_train = np.column_stack([df['LSTAT'], np.ones(len(df))])
y_train = df['MEDV'].values

iterations = 140
learning_rate = 0.0001
for _ in range(iterations):
    gradient = mse_gradient(X_train, y_train, w)
    loss = l_mse(X_train, y_train, w)
    w = w - learning_rate * grad
    print(w, loss)
    
    
y_pred = neuron2(x, w)
y_actual = df["MEDV"]
mse_val = mse(y_actual, y_pred)
plt.title(mse_val)
plt.plot(x_1,y_pred, c='r')
plt.scatter(x_n, y_n, color="black")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 11
#       9 learning_rate = 0.0001
#      10 for _ in range(iterations):
# ---> 11     gradient = mse_gradient(X_train, y_train, w)
#      12     loss = l_mse(X_train, y_train, w)
#      13     w = w - learning_rate * grad
#
# Cell In[26], line 2, in mse_gradient(X, y, w)
#       1 def mse_gradient(X,y,w):
# ----> 2     y_pred = neuron2(X,w)
#       3     gradient = -(2/len(y)) * X.T @ (y - y_pred)
#       4     return gradient
#
# NameError: name 'neuron2' is not defined
